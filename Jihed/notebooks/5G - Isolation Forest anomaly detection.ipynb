# %% [markdown]
# # 5.3 Best-Effort Anomaly Detection - Isolation Forest
#
# Modeling objective: detect premium traffic behavior that appears inside the best-effort slice.

# %%
from pathlib import Path
import numpy as np
import pandas as pd
from sklearn.ensemble import IsolationForest
from sklearn.metrics import accuracy_score, confusion_matrix, f1_score, precision_score, recall_score
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
import matplotlib.pyplot as plt
import seaborn as sns

# %%
cm = confusion_matrix(y_true, train['iso_pred'])
metrics = pd.DataFrame([
    {
        'accuracy': accuracy_score(y_true, train['iso_pred']),
        'precision': precision_score(y_true, train['iso_pred'], zero_division=0),
        'recall': recall_score(y_true, train['iso_pred'], zero_division=0),
        'f1_score': f1_score(y_true, train['iso_pred'], zero_division=0),
    }
])
display(metrics.round(4))

fig, ax = plt.subplots(figsize=(6, 4.8))
sns.heatmap(cm, annot=True, fmt='d', cmap='Greens', cbar=False, linewidths=0.5, linecolor='white', ax=ax)
ax.set_title('Confusion Matrix - Isolation Forest')
ax.set_xlabel('Predicted')
ax.set_ylabel('Actual')
ax.set_xticklabels(['Normal', 'Anomaly'])
ax.set_yticklabels(['Normal', 'Anomaly'], rotation=0)
plt.tight_layout()
plt.show()
# Out:
#   Cell In[19], line 2
#     metrics = pd.DataFrame([{
#                             ^
# SyntaxError: '{' was never closed
